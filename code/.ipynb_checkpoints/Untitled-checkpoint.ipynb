# %%
import numpy as np
import pandas as pd

# %%
pd.read_pickle('../data/train/baseline_smri')
# Out:
#                   smri_vol_cdk_banksstslh  smri_vol_cdk_cdacatelh  \
# subjectkey
# NDAR_INV3YDKCAH1                 1.620812               -1.042371
# NDAR_INV6CN3DP5L                -0.051335               -0.672023
# NDAR_INVXVFTLZM9                -0.228210                2.664652
# NDAR_INV26WFVNRJ                -1.252399               -0.903356
# NDAR_INVRFFGJ02J                -1.150613               -0.696258
# ...                                   ...                     ...
# NDAR_INV21Y67TEX                 0.884516               -0.721418
# NDAR_INV39YDHFR8                -0.624571                0.018597
# NDAR_INVRH5DUYBT                -0.337477                0.497751
# NDAR_INV2DYU5KZK                -0.295390                0.363657
# NDAR_INVVYUKADTG                 0.478909               -0.495627
#
#                   smri_vol_cdk_cdmdfrlh  smri_vol_cdk_cuneuslh  \
# subjectkey
# NDAR_INV3YDKCAH1               0.822751               0.124429
# ...

# %%
pd.read_pickle('../data/train/followup_smri')
# Out:
#                   smri_vol_cdk_banksstslh  smri_vol_cdk_cdacatelh  \
# subjectkey
# NDAR_INV3YDKCAH1                 1.620812               -1.042371
# NDAR_INV6CN3DP5L                -0.051335               -0.672023
# NDAR_INVXVFTLZM9                -0.228210                2.664652
# NDAR_INV26WFVNRJ                -1.252399               -0.903356
# NDAR_INVRFFGJ02J                -1.150613               -0.696258
# ...                                   ...                     ...
# NDAR_INV21Y67TEX                 0.884516               -0.721418
# NDAR_INV39YDHFR8                -0.624571                0.018597
# NDAR_INVRH5DUYBT                -0.337477                0.497751
# NDAR_INV2DYU5KZK                -0.295390                0.363657
# NDAR_INVVYUKADTG                 0.478909               -0.495627
#
#                   smri_vol_cdk_cdmdfrlh  smri_vol_cdk_cuneuslh  \
# subjectkey
# NDAR_INV3YDKCAH1               0.822751               0.124429
# ...
